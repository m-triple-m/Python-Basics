# %%
def addNums(a, b):
    print(a+b)

# %%
addNums(349, 1)
# Out:
# 350

# %%
result = addNums(10, 10)
# Out:
# 20

# %%
result

# %%
def product(a, b):
    return a*b

# %%
result2 = product(10, 10)

# %%
result2
# Out:
# 100

# %%
'abc'.center(20, '#')
# Out:
# '########abc#########'

# %%
def greet(name, time='morning'):
    return f'Good {time} {name}'

# %%
greet('Raju')
# Out:
# 'Good morning Raju'

# %%
greet('Farhan', 'Night')
# Out:
# 'Good Night Farhan'

# %%
greet('Rancho', 'Afternoon')
# Out:
# 'Good Afternoon Rancho'

# %%
greet('morning')
# Out:
# 'Good morning morning'

# %%
def displayDetails(name, hobby, age):
    return f'Hello {name}. You are {age} years old. You like {hobby}'

# %%
displayDetails(52, 'Leon', 'Gaming')
# Out:
# 'Hello 52. You are Gaming years old. You like Leon'

# %%
displayDetails(age = 52, name = 'Leon', hobby = 'Gaming')
# Out:
# 'Hello Leon. You are 52 years old. You like Gaming'

# %%
print(23, 'good', 56, 768, 56, 32,32)
# Out:
# 23 good 56 768 56 32 32

# %%
def marksAvg(*marks):
    avg = sum(marks)/len(marks)
    return avg

# %%
marksAvg(3, 5, 7, 9, 7, 9, 45, 2, 2)
# Out:
# 9.88888888888889

# %%
# create a function to check if a number is even

# %%
# anonymous function
double =  lambda a : 2 * a

# %%
double(45)
# Out:
# 90
