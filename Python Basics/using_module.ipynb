# %%
import math

# %%
math.sqrt(16)
# Out:
# 4.0

# %%
math.pow(5, 4)
# Out:
# 625.0

# %%
16 ** 0.5
# Out:
# 4.0

# %%
math.ceil(4.6)
# Out:
# 5

# %%
math.floor(4.6)
# Out:
# 4

# %%
round(3.5)
# Out:
# 4

# %%
import random

# %%
random.random()
# Out:
# 0.7130885795851503

# %%
random.randint(10, 50)
# Out:
# 29

# %%
games = ['subway surfers', 'BGMI', 'Tekken 8', 'Cooking Chef', 'GTA San Andreas', 'Call Of Duty', 'Contra']

# %%
random.choice(games)
# Out:
# 'GTA San Andreas'

# %%
random.choices(games, k=3)
# Out:
# ['Tekken 8', 'subway surfers', 'BGMI']

# %%
otp = random.randint(1000, 9999)
otp
# Out:
# 3005

# %%
import os

# %%
os.listdir()
# Out:
# ['.git',
#  'conditions.ipynb',
#  'dictionary.ipynb',
#  'functions.ipynb',
#  'intro.ipynb',
#  'list.ipynb',
#  'list_comprehension.ipynb',
#  'loops.ipynb',
#  'operator.ipynb',
#  'questions.ipynb',
#  'set.ipynb',
#  'strings.ipynb',
#  'tuple.ipynb',
#  'using_module.ipynb']
