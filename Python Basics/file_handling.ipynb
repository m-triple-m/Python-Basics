# %%
msg = 'abrakadabra'

# %%
msg[::-1]
# Out:
# 'arbadakarba'

# %%
for i in range(len(msg)-1, -1, -1):
    print(msg[i])
# Out:
# a
# r
# b
# a
# d
# a
# k
# a
# r
# b
# a

# %%
x, y = 0, 10

if x and y/x:
    print('valid')
else:
    print('invalid')
# Out:
# invalid

# %%
for i in range(3):
    if i == 2:
        break
    
else:
    print('completed')

# %%
x = 10
y = 5
if x>5 == y:
    print('match')
else:
    print('no match')
# Out:
# match

# %%
x>5 == y
# Out:
# True

# %%
bool(56)
# Out:
# True

# %%
a = [1, 2, 3]
b = a

# %%
a = a + [4]

# %%
b
# Out:
# [1, 2, 3]

# %%
a.append(4)

# %%
b
# Out:
# [1, 2, 3, 4]

# %%
a
# Out:
# [1, 2, 3, 4, 4, 4]

# %%
d2 = {'a' : 1}
d1 = d2

d1['b'] = 2
d2['a'] = 3

print(d1)
# Out:
# {'a': 3, 'b': 2}

# %%
x = [1, 2, 3]

# %%
y = x[:]

# %%
x[0] = 10

# %%
y
# Out:
# [1, 2, 3]

# %%
True or False
# Out:
# True

# %%
False or True
# Out:
# True

# %%
a = []
b = []

print(a == b, a is b)
# Out:
# True False

# %%
a = b

# %%
a is b
# Out:
# True

# %%
for i in range(2):
    
    print(i)
else:
    print('loop done')
# Out:
# 0
# 1
# loop done

# %%
a = [[1, 2]]* 3

# %%
a
# Out:
# [[1, 2], [1, 2], [1, 2]]

# %%
a[2][1] = 5

# %%
a
# Out:
# [[1, 5], [1, 5], [1, 5]]

# %%
a = [1, 2, 3, 4]

# %%
a[1:3] = [7]

# %%
a
# Out:
# [1, 7, 4]

# %%
[1, 2, 3] == [1, 3, 2]
# Out:
# False

# %%
{1, 2, 3} == {1, 3, 2}
# Out:
# True
