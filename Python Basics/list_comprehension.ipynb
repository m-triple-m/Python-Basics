# %%
mylist = [ i for i in range(5) ]

# %%
mylist
# Out:
# [0, 1, 2, 3, 4]

# %%
[ i**2 for i in range(5) ]
# Out:
# [0, 1, 4, 9, 16]

# %%
nums = [2, 4, 7, 8, 5, 3]

# %%
[ i for i in nums if i%2==0 ]
# Out:
# [2, 4, 8]

# %%
names = ['Sherlock', 'Watson', 'Lestrade', 'Enola', 'Moriarty']

# %%
[n.upper() for n in names]
# Out:
# ['SHERLOCK', 'WATSON', 'LESTRADE', 'ENOLA', 'MORIARTY']

# %%
# create a list of names input by user
[input() for i in range(5)]
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %%
nums
# [True, True, False, True, False, False]
# Out:
# [2, 4, 7, 8, 5, 3]

# %%
[True if i%2==0 else False for i in nums ]
# Out:
# [True, True, False, True, False, False]

# %%
a = 5
print('greater') if a > 5 else print('lesser')
# Out:
# lesser

# %%
# WAP to filter prices less than 2000 and greater than 500
prices = [340, 5600, 1200, 760, 3400]
