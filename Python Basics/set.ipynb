# %%
A = { 23, 45, 8, 4, 4, 8 }

# %%
A
# Out:
# {4, 8, 23, 45}

# %%
nums = [ 4, 7, 1, 2, 89, 6, 32, 56, 3, 1, 7 ]

# %%
list(set(nums))
# Out:
# {1, 2, 3, 4, 6, 7, 32, 56, 89}

# %%
A[2]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 A[2]
#
# TypeError: 'set' object is not subscriptable

# %%
A = {10, 20, 30}
B = {30, 40, 50}
C = {50, 60, 70}

# %%
A.union(B)
# Out:
# {10, 20, 30, 40, 50}

# %%
A | B
# Out:
# {10, 20, 30, 40, 50}

# %%
A.intersection(B)
# Out:
# {30}

# %%
A & B
# Out:
# {30}

# %%
A & C
# Out:
# set()

# %%
set()
# Out:
# set()

# %%
A.difference(B)
# Out:
# {10, 20}

# %%
A - B
# Out:
# {10, 20}

# %%
A.symmetric_difference(B)
# Out:
# {10, 20, 40, 50}

# %%
A ^ B
# Out:
# {10, 20, 40, 50}

# %%
# add
# discard

# %%
A.add(70)
A
# Out:
# {10, 20, 30, 70}

# %%
A.discard(70)
A
# Out:
# {10, 20, 30}

# %%
A.isdisjoint(B)
# Out:
# False

# %%
print(A, B)
# Out:
# {10, 20, 30} {40, 50, 30}

# %%
A.isdisjoint(C)
# Out:
# True

# %%
A.issubset(B)
# Out:
# False

# %%
U = { 10, 20, 30, 40, 50, 60, 70, 80 }

# %%
U
# Out:
# {10, 20, 30, 40, 50, 60, 70, 80}

# %%
A.issubset(U)
# Out:
# True

# %%
A.update(B)

# %%
A
# Out:
# {10, 20, 30, 40, 50}

# %%
A.pop()
# Out:
# 40

# %%
A
# Out:
# {10, 30}
