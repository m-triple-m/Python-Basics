# %%
myTuple = (4, 7, 9, 3)

# %%
type(myTuple)
# Out:
# tuple

# %%
myTuple[3] = 6
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 myTuple[3] = 6
#
# TypeError: 'tuple' object does not support item assignment

# %%
nums = 10,

# %%
nums
# Out:
# (10, 64, 475)

# %%
nums2 = 10, 20, 30

# %%
x, y, z = nums2

# %%
x
# Out:
# 10
