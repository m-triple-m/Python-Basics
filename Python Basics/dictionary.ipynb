# %%
alpha = { 'a' : 'apple', 'b' : 'ball', 'c' : 'cat', 'd' : 'dog' }

# %%
alpha['c']
# Out:
# 'cat'

# %%
alpha.get('d')
# Out:
# 'dog'

# %%
alpha.get('z', 'nhi mila')
# Out:
# 'nhi mila'

# %%
alpha.get('c', 'nhi mila')
# Out:
# 'cat'

# %%
alpha['z'] = 'zebra'

# %%
alpha
# Out:
# {'a': 'apple', 'b': 'ball', 'c': 'cat', 'd': 'dog', 'z': 'zebra'}

# %%
alpha.pop('a')
# Out:
# 'apple'

# %%
alpha
# Out:
# {'b': 'ball', 'c': 'cat', 'd': 'dog', 'z': 'zebra'}

# %%
mycopy = alpha

# %%
alpha.pop('z')
# Out:
# 'zebra'

# %%
mycopy
# Out:
# {'b': 'ball', 'c': 'cat', 'd': 'dog'}

# %%
mycopy2 = alpha.copy()

# %%
mycopy2
# Out:
# {'b': 'ball', 'c': 'cat', 'd': 'dog'}

# %%
alpha['z'] = 'zebra'

# %%
mycopy2
# Out:
# {'b': 'ball', 'c': 'cat', 'd': 'dog'}

# %%
alpha.items()
# Out:
# dict_items([('b', 'ball'), ('c', 'cat'), ('d', 'dog'), ('z', 'zebra')])

# %%
for pair in alpha.items():
    print(pair)
# Out:
# ('b', 'ball')
# ('c', 'cat')
# ('d', 'dog')
# ('z', 'zebra')

# %%
alpha.keys()
# Out:
# dict_keys(['b', 'c', 'd', 'z'])

# %%
alpha.values()
# Out:
# dict_values(['ball', 'cat', 'dog', 'zebra'])

# %%
smartphone = {
    'brand' : 'Apple',
    'model' : 'Iphone 17',
    'colors' : [ 'black', 'white', 'cosmic orange' ],
    'price' : 170000
}

# %%
smartphone.get('colors')[2]
# Out:
# 'cosmic orange'

# %%
smartphone.get('colors')[2].split()
# Out:
# ['cosmic', 'orange']

# %%
smartphone['colors'].append('blue')

# %%
smartphone
# Out:
# {'brand': 'Apple',
#  'model': 'Iphone 17',
#  'colors': ['black', 'white', 'cosmic orange', 'blur', 'blue'],
#  'price': 170000}

# %%
smartphone['colors'].remove('blur')

# %%
smartphone
# Out:
# {'brand': 'Apple',
#  'model': 'Iphone 17',
#  'colors': ['black', 'white', 'cosmic orange', 'blue'],
#  'price': 170000}
