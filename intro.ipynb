# %% [markdown]
# ## Python Introduction

# %%
print('hello python')
# Out:
# hello python

# %%
name="Leon"

# %%
name
print(name)
print(name)
# Out:
# Leon
# Leon

# %%
print(name)
# Out:
# Leon

# %%
user1 = 'mmm'

# %%
user_2 = 'nnn'

# %%
_ = 'something'

# %%
_
# Out:
# 'something'

# %%
num = 567

# %%
type(num)
# Out:
# int

# %%
type(name)
# Out:
# str

# %%
price = 4.99

# %%
type(price)
# Out:
# float

# %%
color = "black"

# %%
color
# Out:
# 'black'

# %%
poem = """Twinkle Twinkle little Star
How I wonder what you are"""

# %%
poem
# Out:
# 'Twinkle Twinkle little Star\nHow I wonder what you are'

# %%
print(poem)
# Out:
# Twinkle Twinkle little Star
# How I wonder what you are

# %%
isHungry = True

# %%
type(isHungry)
# Out:
# bool

# %% [markdown]
# ### Representation in Python
# - int
# - str
# - float
# - bool
# - None

# %%
empty = None

# %%
print(empty)
# Out:
# None

# %%
a, b = 10, 20

# %%
# Lists - Ordered sequence of elements
names = ['raju', 'ramu', 'shamu', 'kaliya', 'pinki']

# %%
# Tuples - same as list but immutable
nums = (2, 4, 7)

# %%
# Sets - cannot contain duplicate elements
myset = {3, 4, 5, 4, 6, 5, 4, 3}

# %%
print(myset)
# Out:
# {3, 4, 5, 6}

# %%
# Dictionaries - collection of key-value pairs
phonebook = { 'ramu' : 1234, 'raju' : 5678, 'pinki' : 3456 }

# %%
phonebook
# Out:
# {'ramu': 1234, 'raju': 5678, 'pinki': 3456}
