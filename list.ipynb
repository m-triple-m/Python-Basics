# %%
movies = [ 'Thor', 'Batman', 'X-Men', 'Iron Man', 'Krishh', 'Dhurandhar' ]

# %%
# indexing
movies[2]
# Out:
# 'X-Men'

# %%
# slicing
movies[1:5]
# Out:
# ['Batman', 'X-Men', 'Iron Man', 'Krishh']

# %%
movies.append('Spiderman')

# %%
movies
# Out:
# ['Thor', 'Batman', 'X-Men', 'Iron Man', 'Krishh', 'Dhurandhar', 'Spiderman']

# %%
movies.insert(3, 'Superman')

# %%
movies
# Out:
# ['Thor',
#  'Batman',
#  'X-Men',
#  'Superman',
#  'Iron Man',
#  'Krishh',
#  'Dhurandhar',
#  'Spiderman']

# %%
movies.pop()
# Out:
# 'Spiderman'

# %%
movies
# Out:
# ['Thor', 'Batman', 'X-Men', 'Superman', 'Iron Man', 'Krishh', 'Dhurandhar']

# %%
movies.remove('X-Men')

# %%
movies
# Out:
# ['Thor', 'Batman', 'Superman', 'Iron Man', 'Krishh', 'Dhurandhar']

# %%
# WAP to create an empty list and store your five friend names

# %%
name = 'Mubassir'

# %%
name.replace('u', '').replace('i', '')
# Out:
# 'Mbassr'

# %%
name = 'Madan Mohan Malviya'
for i in 'aeiou':
    name = name.lower().replace(i, '')
    
print(name)
# Out:
# mdn mhn mlvy

# %%
movies.count('Batman')
# Out:
# 1

# %%
movies.reverse()

# %%
movies
# Out:
# ['Dhurandhar', 'Krishh', 'Iron Man', 'Superman', 'Batman', 'Thor']

# %%
movies[::-1]
# Out:
# ['Thor', 'Batman', 'Superman', 'Iron Man', 'Krishh', 'Dhurandhar']

# %%
movies.index('Iron Man')
# Out:
# 2

# %%
movies.sort(reverse=True)

# %%
movies
# Out:
# ['Thor', 'Superman', 'Krishh', 'Iron Man', 'Dhurandhar', 'Batman']

# %%
sorted(movies, reverse=True)
# Out:
# ['Thor', 'Superman', 'Krishh', 'Iron Man', 'Dhurandhar', 'Batman']

# %%
nums = [1, 2, 3]

# %%
mycopy = nums

# %%
mycopy
# Out:
# [1, 2, 3]

# %%
nums.append(4)

# %%
mycopy
# Out:
# [1, 2, 3, 4]

# %%
mycopy2 = nums.copy()

# %%
mycopy2
# Out:
# [1, 2, 3, 4]

# %%
nums.append(5)

# %%
mycopy2
# Out:
# [1, 2, 3, 4]
