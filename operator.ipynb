# %% [markdown]
# ## Arithmetic Operators

# %%
a, b = 10, 20

print(a+b)
print(a-b)
print(a/b)
print(a*b)
# Out:
# 30
# -10
# 0.5
# 200

# %%
10%3
# Out:
# 1

# %%
10/3
# Out:
# 3.3333333333333335

# %%
10//3
# Out:
# 3

# %% [markdown]
# ## Assignment Operator

# %%
a += 5

# %%
a
# Out:
# 25

# %%
a*=2

# %%
a
# Out:
# 50

# %% [markdown]
# ## Comparison Operators

# %%
a == 50
# Out:
# True

# %%
a != 10
# Out:
# True

# %%
a < 100
# Out:
# True

# %%
a < 50
# Out:
# False

# %%
a <= 50
# Out:
# True

# %% [markdown]
# ## Logical Operators

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
True and False
# Out:
# False

# %%
True and True
# Out:
# True

# %%
True or False
# Out:
# True

# %%
False or False
# Out:
# False

# %%
True or True
# Out:
# True

# %%
name = "Leon S Kennedy"

# %%
'Leon' in name
# Out:
# True

# %%
'Chris' not in name
# Out:
# True
