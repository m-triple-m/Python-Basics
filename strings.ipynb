# %%
name = "Mubassir"

# %%
print(name)
# Out:
# Mubassir

# %%
len(name)
# Out:
# 8

# %%
for i in name:
    print(i)
# Out:
# M
# u
# b
# a
# s
# s
# i
# r

# %%
name2 = "Leon Scott Kennedy"

# %%
# indexing

# %%
name2[3]
# Out:
# 'n'

# %%
name2[4]
# Out:
# ' '

# %%
name2[11]
# Out:
# 'K'

# %%
name2[-7]
# Out:
# 'K'

# %%
# slicing
name2[0:4]
# Out:
# 'Leon'

# %%
name2[11:18]
# Out:
# 'Kennedy'

# %%
name2[-7:]
# Out:
# 'Kennedy'

# %%
name2[11:]
# Out:
# 'Kennedy'

# %%
movie = 'Kabhi Khushi Kabhi Gam'

# %%
movie[-3:]
# Out:
# 'Gam'

# %%
movie[:5]
# Out:
# 'Kabhi'

# %%
name2[5:10]
# Out:
# 'Scott'

# %%
name2[5:-8]
# Out:
# 'Scott'

# %%
a = '$45.63476'
b = '$23.76'
c = '$42.4'

# %%
c[1:3]
# Out:
# '42'

# %%
movie[::2]
# Out:
# 'KbiKuh ah a'

# %%
movie[::-1]
# Out:
# 'maG ihbaK ihsuhK ihbaK'

# %%
name2[0:10:-1]
# Out:
# ''

# %%
name2[10:0:-1]
# Out:
# ' ttocS noe'

# %%
# String Function

# %%
name2.upper()
# Out:
# 'LEON SCOTT KENNEDY'

# %%
name2.lower()
# Out:
# 'leon scott kennedy'

# %%
name2.capitalize()
# Out:
# 'Leon scott kennedy'

# %%
name2.swapcase()
# Out:
# 'lEON sCOTT kENNEDY'

# %%
# Alignment Functions
name2.rjust(30)
# Out:
# '            Leon Scott Kennedy'

# %%
name2.ljust(30)
# Out:
# 'Leon Scott Kennedy            '

# %%
name2.ljust(30, 'a')
# Out:
# 'Leon Scott Kennedyaaaaaaaaaaaa'

# %%
(name2+' ').ljust(30, 'a')
# Out:
# 'Leon Scott Kennedy aaaaaaaaaaa'

# %%
name2.center(30, '-')
# Out:
# '------Leon Scott Kennedy------'

# %%
name2.isupper()
# Out:
# False

# %%
print(name2.islower())
print(name2.isalpha())
print(name2.isalnum())
print(name2.isnumeric())
# Out:
# False
# False
# False
# False

# %%
'abc 123'.isalnum()
# Out:
# False

# %%
'6541'.isnumeric()
# Out:
# True

# %%
name2.title()
# Out:
# 'Leon Scott Kennedy'

# %%
name2.count('n')
# Out:
# 3

# %%
name2
# Out:
# 'Leon Scott Kennedy'

# %%
name2.index('n')
# Out:
# 3

# %%
name2.rindex('n')
# Out:
# 14

# %%
name2.rindex('a')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[90], line 1
# ----> 1 name2.rindex('a')
#
# ValueError: substring not found

# %%
name2.index('n', 14)
# Out:
# 14

# %%
name2.find('a')
# Out:
# -1

# %%
name2.replace('n', 'N')
# Out:
# 'LeoN Scott KeNNedy'

# %%
name2
# Out:
# 'Leon Scott Kennedy'

# %%
name2.split(' ')
# Out:
# ['Leon', 'Scott', 'Kennedy']

# %%
'https://meet.google.com/yun-rcuf-fhi'.split('/')
# Out:
# ['https:', '', 'meet.google.com', 'yun-rcuf-fhi']

# %%
'https://www.google.com/search?q=voltage+regulator+dc&sca_esv=27fdc1d65c2ac978&rlz=1C1VDKB_enIN1146IN1146&udm=2&biw=1920&bih=991&sxsrf=ANbL-n65sQWHnqDvA0N2BlzFGbH74Q3RJA%3A1776435828778&ei=dELiaZuWL62PseMPqfDs-AU&ved=0ahUKEwiboKmUi_WTAxWtR2wGHSk4G18Q4dUDCBI&uact=5&oq=voltage+regulator+dc&gs_lp=Egtnd3Mtd2l6LWltZyIUdm9sdGFnZSByZWd1bGF0b3IgZGMyBRAAGIAEMgUQABiABDIEEAAYHjIEEAAYHjIEEAAYHjIEEAAYHjIEEAAYHjIEEAAYHjIEEAAYHjIEEAAYHkidCVChAlj8BXABeACQAQCYAf4BoAHFBKoBBTAuMi4xuAEDyAEA-AEBmAIEoALuBMICBxAjGMkCGCfCAgYQABgHGB7CAgoQABiABBiKBRhDmAMAiAYBkgcFMS4yLjGgB6QQsgcFMC4yLjG4B-AEwgcFMi0yLjLIByCACAE&sclient=gws-wiz-img#sv=CAMSWBoyKhBlLTVfNFZqWWNHTjJOREZNMg41XzRWalljR04yTkRGTToOcm92UWVwYW55ZzRqV00gBCocCgZtb3NhaWMSEGUtNV80VmpZY0dOMk5ERk0YADABOAAYByClp8yiAUoIEAEYASABKAE'.split('/')
# Out:
# ['https:',
#  '',
#  'www.google.com',
#  'search?q=voltage+regulator+dc&sca_esv=27fdc1d65c2ac978&rlz=1C1VDKB_enIN1146IN1146&udm=2&biw=1920&bih=991&sxsrf=ANbL-n65sQWHnqDvA0N2BlzFGbH74Q3RJA%3A1776435828778&ei=dELiaZuWL62PseMPqfDs-AU&ved=0ahUKEwiboKmUi_WTAxWtR2wGHSk4G18Q4dUDCBI&uact=5&oq=voltage+regulator+dc&gs_lp=Egtnd3Mtd2l6LWltZyIUdm9sdGFnZSByZWd1bGF0b3IgZGMyBRAAGIAEMgUQABiABDIEEAAYHjIEEAAYHjIEEAAYHjIEEAAYHjIEEAAYHjIEEAAYHjIEEAAYHjIEEAAYHkidCVChAlj8BXABeACQAQCYAf4BoAHFBKoBBTAuMi4xuAEDyAEA-AEBmAIEoALuBMICBxAjGMkCGCfCAgYQABgHGB7CAgoQABiABBiKBRhDmAMAiAYBkgcFMS4yLjGgB6QQsgcFMC4yLjG4B-AEwgcFMi0yLjLIByCACAE&sclient=gws-wiz-img#sv=CAMSWBoyKhBlLTVfNFZqWWNHTjJOREZNMg41XzRWalljR04yTkRGTToOcm92UWVwYW55ZzRqV00gBCocCgZtb3NhaWMSEGUtNV80VmpZY0dOMk5ERk0YADABOAAYByClp8yiAUoIEAEYASABKAE']

# %%
name2.strip()
# Out:
# 'Leon Scott Kennedy'

# %%
'  567     '.strip()
# Out:
# '567'

# %%
'-565----'.strip('-')
# Out:
# '565'

# %%
'  davy jones    '.strip(' ')
# Out:
# 'davy jones'

# %%
'--$3767--$-$'.strip('$-')
# Out:
# '3767'

# %%
line1 = 'Johny Johny Yes Papa'
# 'Papa Yes Johny Johny'

# %%
[1, 2, 3][::-1]
# Out:
# [3, 2, 1]

# %%
line1[::-1]
# Out:
# 'apaP seY ynhoJ ynhoJ'

# %%
'Mubassir'.replace('u', '')
# Out:
# 'Mbassir'

# %%
' '.join(['abc', 'xyz'])
# Out:
# 'abc xyz'
